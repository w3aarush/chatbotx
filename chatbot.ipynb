# %%
user_input = ['hi','hello','hey','how are you','what are you doing']
response_msg = ['hi','hello there','hey','fine, what about you','nothing, just talking to you']

# %%
i1 = list(enumerate(user_input))
r1 = list(enumerate(response_msg))

# %%
i1

# %%
r1

# %%
def chatbot():
    while True:
        message = input('enter you message')
        print('reached stage 1')
        if message == 'exit':
            print('bye! take care')
        print('reached stage 2')
        text_num = None
        print('reached stage 3')
        if message in i1:
            for num, text in e1:
                if text==message:
                    text_num = num
        else:
            print("sorry, didn't get that")
        for num, text in r1:
            if num == text_num:
                print(f'bot : {text}')

# %%
chatbot()
